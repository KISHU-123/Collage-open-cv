# %%
import cv2

# %%
img = cv2.imread('Desktop/capture.PNG')
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [211 211 211]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [211 211 211]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [211 211 211]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [211 211 211]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [211 211 211]
#   [211 211 211]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(img.shape)#rows,columns,number of channels
# Out:
# (315, 356, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
plt.figure(figsize=(50,20))

plt.imshow(rgb_image)

# %%
plt.imshow(img)

# %%
crop_image = rgb_image[50:300,25:200,:]

# %%
plt.imshow(crop_image)
plt.axis('off')
# Out:
# (-0.5, 174.5, 249.5, -0.5)

# %%
crop_image.shape
# Out:
# (250, 175, 3)

# %%
#resize
c = cv2.resize(crop_image,(100,100))
plt.imshow(c)
